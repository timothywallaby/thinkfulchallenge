# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
dirty = pd.read_csv("/Users/swang/Python/WELLCOME/WELLCOME.csv", encoding='latin-1')

# %%
dirty.head(10)
# Out:
#               PMID/PMCID                                     Publisher  \
# 0                    NaN                                           CUP
# 1             PMC3679557                                           ACS
# 2  23043264  PMC3506128                                            ACS
# 3    23438330 PMC3646402                                           ACS
# 4   23438216 PMC3601604                                            ACS
# 5             PMC3579457                                           ACS
# 6             PMC3709265                                           ACS
# 7   23057412 PMC3495574                                            ACS
# 8      PMCID: PMC3780468  ACS (Amercian Chemical Society) Publications
# 9      PMCID: PMC3621575  ACS (Amercian Chemical Society) Publications
#
#                     Journal title  \
# 0          Psychological Medicine
# 1               Biomacromolecules
# 2                      J Med Chem
# 3                      J Med Chem
# ...

# %%
dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 5 columns):
# PMID/PMCID                                             1928 non-null object
# Publisher                                              2127 non-null object
# Journal title                                          2126 non-null object
# Article title                                          2127 non-null object
# COST (£) charged to Wellcome (inc VAT when charged)    2127 non-null object
# dtypes: object(5)
# memory usage: 83.2+ KB

# %%
dirty.describe()
# Out:
#         PMID/PMCID Publisher Journal title  \
# count         1928      2127          2126
# unique        1880       299           984
# top     In Process  Elsevier      PLoS One
# freq             7       387            92
#
#                                             Article title  \
# count                                                2127
# unique                                               2126
# top     Exclusive breastfeeding, diarrhoel morbidity a...
# freq                                                    2
#
#        COST (£) charged to Wellcome (inc VAT when charged)
# count                                                2127
# unique                                               1402
# top                                              £2040.00
# freq                                                   94

# %% [markdown]
# determine the five most common journals and the total articles for each. Next, calculate the mean, median, and standard deviation of the open-access cost per article for each journal .

# %%
dirty.groupby("Journal title").count().sort_values(by=['Article title'], ascending=False)
# Out:
#                                                     PMID/PMCID  Publisher  \
# Journal title
# PLoS One                                                    91         92
# PLoS ONE                                                    62         62
# Journal of Biological Chemistry                             47         48
# Nucleic Acids Research                                      20         21
# Proceedings of the National Academy of Sciences             19         19
# PLoS Neglected Tropical Diseases                            18         18
# Human Molecular Genetics                                    16         18
# Nature Communications                                       17         17
# PLoS Pathogens                                              15         15
# PLoS Genetics                                               14         15
# Neuroimage                                                  14         15
# ...

# %%
dirty.columns = ['pmid', 'publisher', 'journal', 'article', 'cost']

# %%
dirty['price'] = dirty.cost.str.replace("£","")

# %%
dirty
# Out:
#                                   pmid  \
# 0                                  NaN
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 21                                 NaN
# 22            PMCID:\n    PMC3656742\n
# ...

# %%
dirty['journal'] = dirty.journal.str.replace('PLoS ONE', 'PLoS One')
dirty['journal'] = dirty.journal.str.replace('PLoS ONE', 'PLoS One')

# %%
dirty.groupby("journal").count().sort_values(by=['article'], ascending=False).head(5)
# Out:
#                                                  pmid  publisher  article  \
# journal
# PLoS One                                          153        154      154
# Journal of Biological Chemistry                    47         48       48
# Nucleic Acids Research                             20         21       21
# Proceedings of the National Academy of Sciences    19         19       19
# Human Molecular Genetics                           16         18       18
#
#                                                  cost  price
# journal
# PLoS One                                          154    154
# Journal of Biological Chemistry                    48     48
# Nucleic Acids Research                             21     21
# Proceedings of the National Academy of Sciences    19     19
# Human Molecular Genetics                           18     18

# %% [markdown]
# Above are the five most common journals and the article count for each.

# %%
dirty2 = dirty[['journal', 'price']]

# %%
dirty2.head()
# Out:
#                   journal    price
# 0  Psychological Medicine     0.00
# 1       Biomacromolecules  2381.04
# 2              J Med Chem   642.56
# 3              J Med Chem   669.64
# 4              J Org Chem   685.88

# %%
print(dirty2.dtypes)
# Out:
# journal    object
# price      object
# dtype: object

# %%
pd.to_numeric(dirty2['price'], errors='coerce')
# Out:
# 0          0.00
# 1       2381.04
# 2        642.56
# 3        669.64
# 4        685.88
# 5       2392.20
# 6       2367.95
# 7        649.33
# 8       1294.59
# 9       1294.78
# 10      1329.69
# 11      1287.20
# 12      1324.66
# 13       665.64
# 14      1006.72
# 15       238.08
# 16       265.67
# 17      2035.00
# 18      3108.08
# 19      1267.76
# 20      2286.73
# 21       947.07
# 22      1186.80
# 23       642.89
# 24      1533.29
# 25      2082.74
# 26      2314.10
# 27       759.67
# 28      1565.26
# 29       572.74
#          ...
# 2097    2236.02
# 2098    2275.02
# 2099    2373.57
# 2100     791.19
# 2101    1551.49
# 2102    1961.68
# 2103    1982.35
# 2104    2239.22
# 2105    2377.65
# 2106    2272.15
# 2107    1900.70
# 2108    3026.17
# 2109    1851.15
# 2110    1812.89
# 2111    1816.70
# 2112    2168.05
# 2113    1409.96
# 2114    2400.00
# 2115    1968.63
# 2116    2015.72
# 2117    1836.92
# 2118    1836.92
# 2119    1375.80
# 2120    1836.92
# ...

# %%
print(dirty2.dtypes)
# Out:
# journal     object
# price      float64
# dtype: object

# %%
dirty2.groupby('journal').aggregate(np.mean).head(10)
# Out:
#                                  price
# journal
# ACS Chemical Biology       1418.186000
# ACS Chemical Neuroscience  1186.800000
# ACS NANO                    642.890000
# ACS Nano                    693.390000
# ACTA F                      754.900000
# AGE                        2002.000000
# AIDS                       2059.306667
# AIDS Behav                 1834.770000
# AIDS Care                  2189.170000
# AIDS Journal               2015.720000

# %%
dirty2.groupby('journal').aggregate(np.std).head(10)
# Out:
#                                 price
# journal
# ACS Chemical Biology       507.309560
# ACS Chemical Neuroscience         NaN
# ACS NANO                          NaN
# ACS Nano                          NaN
# ACTA F                            NaN
# AGE                               NaN
# AIDS                       281.067979
# AIDS Behav                        NaN
# AIDS Care                   61.617285
# AIDS Journal                      NaN

# %%
dirty2.groupby('journal').aggregate(np.median).head(10)
# Out:
#                              price
# journal
# ACS Chemical Biology       1294.59
# ACS Chemical Neuroscience  1186.80
# ACS NANO                    642.89
# ACS Nano                    693.39
# ACTA F                      754.90
# AGE                        2002.00
# AIDS                       1968.63
# AIDS Behav                 1834.77
# AIDS Care                  2189.17
# AIDS Journal               2015.72
